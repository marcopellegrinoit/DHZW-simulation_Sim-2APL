# %%
import csv
import pandas as pd
import os
from tqdm import tqdm
path = 'C:/Users/6997619/Documents/GitHub projects/DHZW-simulation_Sim-2APL/src/main/resources/calibration/data/'

# %% [markdown]
# ## Read datasets

# %%
X_train = pd.read_csv(path+"X_train.csv")
X_test = pd.read_csv(path+"X_test.csv")

with open(path+'parameter_labels.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    params = [row['parameter'] for row in reader]

# %% [markdown]
# ## Create datasets with all the parameters

# %%
X_train_full = pd.DataFrame()
for label in params:
    X_train_full[label] = [1.0] * X_train.shape[0]

X_test_full = pd.DataFrame()
for label in params:
    X_test_full[label] = [1.0] * X_test.shape[0]

# %%
X_train_full.update(X_train)
X_test_full.update(X_test)

# %%
table = pd.concat([X_train_full, X_test_full])

# %% [markdown]
# ### Initialise the output dataframe

# %%
df = pd.DataFrame(columns=["CAR_DRIVER", "CAR_PASSENGER", "BIKE", "BUS_TRAM", "TRAIN", "WALK"])
df.to_csv("output_proportions.csv", index=False)

# %% [markdown]
# ## Call Sim2APL iteratively

# %% [markdown]
# ### Prepare the Java command

# %%
config = "--config src/main/resources/config_DHZW_full.toml"
modeliberal = "--mode-liberal 0.5"
modeconservative = "--mode-conservative 0.5"
output = "-o output/deskrun"
cmd = "java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation" + " " + config + " " + modeliberal + " " + modeconservative + " " + output
os.chdir('C:/Users/6997619/Documents/GitHub projects/DHZW-simulation_Sim-2APL')

# %% [markdown]
# ### Main loop call simulations

# %%
for idx, row in tqdm(table.iterrows(), total=table.shape[0]):
    # Construct the command line argument for this parameter value
    arg = f'--parameterset_index={idx+1}'
        
    # Construct the full command with the argument
    full_command = f'{cmd} {arg}'
           
    print(full_command)
    
    # Capture the output of the Java program
    try:
        print(full_command)
        #output = subprocess.check_output(full_command, stderr=subprocess.STDOUT, universal_newlines=True)
    except subprocess.CalledProcessError as e:
        print(f"Java program exited with non-zero return code: {e.returncode}")
        print(f"Error message: {e.output}")
        exit(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 700/700 [00:00<00:00, 4127.87it/s]
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=1
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=1
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=2
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=2
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=3
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=3
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=4
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=4
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=5
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=5
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=6
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=6
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=7
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=7
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=8
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=8
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=9
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=9
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=10
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=10
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=11
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=11
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=12
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=12
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=13
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=13
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=14
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=14
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=15
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=15
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=16
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=16
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=17
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=17
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=18
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=18
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=19
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=19
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=20
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=20
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=21
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=21
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=22
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=22
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=23
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=23
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=24
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=24
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=25
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=25
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=26
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=26
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=27
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=27
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=28
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=28
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=29
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=29
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=30
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=30
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=31
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=31
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=32
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=32
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=33
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=33
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=34
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=34
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=35
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=35
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=36
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=36
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=37
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=37
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=38
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=38
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=39
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=39
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=40
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=40
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=41
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=41
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=42
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=42
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=43
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=43
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=44
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=44
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=45
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=45
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=46
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=46
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=47
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=47
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=48
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=48
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=49
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=49
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=50
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=50
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=51
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=51
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=52
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=52
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=53
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=53
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=54
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=54
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=55
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=55
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=56
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=56
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=57
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=57
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=58
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=58
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=59
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=59
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=60
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=60
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=61
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=61
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=62
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=62
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=63
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=63
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=64
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=64
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=65
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=65
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=66
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=66
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=67
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=67
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=68
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=68
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=69
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=69
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=70
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=70
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=71
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=71
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=72
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=72
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=73
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=73
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=74
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=74
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=75
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=75
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=76
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=76
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=77
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=77
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=78
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=78
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=79
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=79
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=80
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=80
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=81
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=81
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=82
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=82
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=83
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=83
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=84
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=84
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=85
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=85
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=86
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=86
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=87
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=87
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=88
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=88
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=89
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=89
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=90
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=90
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=91
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=91
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=92
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=92
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=93
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=93
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=94
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=94
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=95
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=95
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=96
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=96
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=97
# ...
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=169
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=169
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=170
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=170
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=171
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=171
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=172
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=172
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=173
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=173
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=174
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=174
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=175
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=175
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=176
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=176
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=177
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=177
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=178
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=178
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=179
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=179
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=180
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=180
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=181
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=181
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=182
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=182
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=183
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=183
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=184
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=184
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=185
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=185
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=186
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=186
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=187
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=187
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=188
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=188
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=189
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=189
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=190
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=190
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=191
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=191
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=192
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=192
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=193
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=193
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=194
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=194
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=195
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=195
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=196
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=196
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=197
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=197
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=198
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=198
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=199
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=199
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=200
# java -cp target/sim2apl-dhzw-simulation-1.0-SNAPSHOT-jar-with-dependencies.jar main.java.nl.uu.iss.ga.Simulation --config src/main/resources/config_DHZW_full.toml --mode-liberal 0.5 --mode-conservative 0.5 -o output/deskrun --parameterset_index=200
